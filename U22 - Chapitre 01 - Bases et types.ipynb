# %% [markdown]
# ## **Exercice 1**

# %%
A=1
B=A+1
A=B+2
B=A+2
A=B+3
B=A+3
print(A,B)
# Out:
# 9 12

# %% [markdown]
# ## **Exercice 2**

# %%
A=5
B=3
C=A+B
A=2
C=B-A
print(A,B)
# Out:
# 2 3

# %% [markdown]
# ## **Exercice 3**

# %%
A=3
B=10
A=A+B
C=A+B
B=C*2
print(A,B,C)
# Out:
# 13 46 23

# %% [markdown]
# ## **Exercice 4**

# %%
n=2
a=n-4
a=a*n
a=a+4
print(a)
n=3
a=n-4
a=a*n
a=a+4
print(a)
n=4
a=n-4
a=a*n
a=a+4
print(a)
n=5
a=n-4
a=a*n
a=a+4
print(a)
# Out:
# 0
# 1
# 4
# 9

# %% [markdown]
# ## **Exercice 5**

# %%
A=5
B=2
A=B
B=A
print(A,B)

A=5
B=2
B=A
A=B
print(A,B)

A=5
B=2
A,B=B,A #manière optimale d'échanger des variables (affectation simultanée)
print(A,B)

Y=10
Z=14
X=Y
Y=Z
Z=X
print(Y,Z)

Y=10
Z=14
Y=Y+Z
Z=Y-Z
Y=Y-Z
print(Y,Z)
# Out:
# 2 2
# 5 5
# 2 5
# 14 10
# 14 10

# %% [markdown]
# ## **Exercice 6**

# %%
A=10
B=15
C=26
B,A,C=A,B,C
print(A,B,C)
# Out:
# 15 10 26

# %% [markdown]
# ## **Exercice 7**

# %%
A=float(input("A="))
B=float(input("B="))
C=float(input("C="))
D=float(input("D="))
A,B,C,D=C,D,A,B
print(A,B,C,D)
# Out:
# A=2
# B=3
# C=4
# D=5
# 4.0 5.0 2.0 3.0

# %% [markdown]
# ## **Exercice 8**

# %%
prenom = input("Quel est ton nom ? ")
age = int(input("Quel est ton âge ? "))
print("Bonjour",prenom,", tu as",age,"ans")
# Out:
# Quel est ton nom ? John
# Quel est ton âge ? 84
# Bonjour John , tu as 84 ans

# %% [markdown]
# ## **Exercice 9**

# %%
A=float(input("A="))
B=float(input("B="))
C=float(input("C="))
print("La moyenne de A B et C est de :",(A+B+C)/3)
# Out:
# A=1
# B=2
# C=78
# La moyenne de A B et C est de : 27.0

# %% [markdown]
# ## **Exercice 10**

# %%
longueur = float(input("Longueur du rectangle : "))
largeur = float(input("Largeur du rectangle : "))
print("L'aire du rectangle vaut :",largeur*longueur)
# Out:
# Longueur du rectangle : 10
# Largeur du rectangle : 15
# L'aire du rectangle vaut : 150.0

# %% [markdown]
# ## **Exercice 11**

# %%
somme = int(input("Saisir une somme en centimes : "))
cinquante = somme // 50 #nombre de pièces de 50 centimes
reste = somme % 50 #somme restante
vingt = reste // 20 #nombre de pièces de 20 centimes
reste = reste % 20 #somme restante
dix = reste // 10 #...
reste = reste % 10
cinq = reste // 5
reste = reste % 5
deux = reste // 2
reste = reste % 2
un = reste
print("Pour",somme,"centimes d'euros, il faut :")
print(cinquante,"pièce(s) de 50 centimes")
print(vingt,"pièce(s) de 20 centimes")
print(dix,"pièce(s) de 10 centimes")
print(cinq,"pièce(s) de 5 centimes")
print(deux,"pièce(s) de 2 centimes")
print(un,"pièce(s) de 1 centime")
# Out:
# Saisir une somme en centimes : 149
# Pour 149 centimes d'euros, il faut :
# 2 pièce(s) de 50 centimes
# 2 pièce(s) de 20 centimes
# 0 pièce(s) de 10 centimes
# 1 pièce(s) de 5 centimes
# 2 pièce(s) de 2 centimes
# 0 pièce(s) de 1 centime

# %% [markdown]
# ##**Exercice 12**

# %%
val=123
double=val*2
print(val)
print(double)
# Out:
# 123
# 246

# %% [markdown]
# ##**Exercice 13**

# %%
n = float(input("Entrer un nombre n : "))
print("Le carré de",n,"vaut",n**2)
# Out:
# Entrer un nombre n : 56
# Le carré de 56.0 vaut 3136.0

# %% [markdown]
# ##**Exercice 14**

# %%
prix_ht = float(input("Donner un prix HT : "))
nb = int(input("Donner un nombre d'articles : "))
taux_tva = float(input("Donner le taux de TVA, sans le % : "))
prix_ttc=nb*prix_ht*(1+taux_tva/100)
print("Le prix total TTC est de :",prix_ttc)
# Out:
# Donner un prix HT : 56
# Donner un nombre d'articles : 9
# Donner le taux de TVA, sans le % : 19.6
# Le prix total TTC est de : 602.784

# %% [markdown]
# ##**Exercice 15**

# %%
a=input("Entrez un nombre entier : ")
b=input("Entrez un autre nombre entier : ")
c=a+b
d=b*4
print(c)
print(d)
# Out:
# Entrez un nombre entier : 99
# Entrez un autre nombre entier : 87
# 9987
# 87878787

# %% [markdown]
# ##**Exercice 16**

# %%
r , pi = 12 , 3.14159
s = pi * r**2
print(s)
print(type(r),type(pi),type(s))
# Out:
# 452.38896
# <class 'int'> <class 'float'> <class 'float'>

# %% [markdown]
# ##**Exercice 17**

# %%
a = input("entrez un nombre entier (à 8 chiffres par exemple) : ")
b = input("entrez un autre entier (à 6 chiffres par exemple): ")
c = a+b
d = b*4
print(c)
print(d)
# Out:
# entrez un nombre entier (à 8 chiffres par exemple) : 12345676
# entrez un autre entier (à 6 chiffres par exemple): 123321
# 12345676123321
# 123321123321123321123321
